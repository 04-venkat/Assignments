# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy.random import randn

df = pd.DataFrame(randn(10, 4), columns = ['a', 'b', 'c', 'd'])

# %%
df
# Out:
#           a         b         c         d
# 0 -0.262287  1.155072 -0.339930  0.742141
# 1 -1.141160  0.316981 -0.746666  0.246600
# 2 -1.013070  0.043206  0.087468  1.251591
# 3  1.990886  0.458209  1.299871  1.367765
# 4 -0.187404  0.838831 -0.197580  0.591138
# 5 -1.572640 -0.739631  0.014950  0.711813
# 6 -0.683741  0.045017  0.552135 -0.960361
# 7 -0.917372 -0.062438  0.962409 -1.529476
# 8 -0.863874 -0.396037  0.286015 -1.669944
# 9 -0.181187  0.524356 -0.747865  0.592287

# %%
df.describe()
# Out:
#                a          b          c          d
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.483185   0.218357   0.117081   0.134355
# std     0.978820   0.563531   0.678622   1.111833
# min    -1.572640  -0.739631  -0.747865  -1.669944
# 25%    -0.989145  -0.036027  -0.304343  -0.658620
# 50%    -0.773807   0.180999   0.051209   0.591712
# 75%    -0.206125   0.507819   0.485605   0.734559
# max     1.990886   1.155072   1.299871   1.367765

# %%
df.plot(kind = "bar")
plt.title("Randomized Bar Graph")
plt.show()
